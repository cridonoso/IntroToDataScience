# %% [markdown]
# # Web Scrapping
#
# Cristobal Donoso Oliva<br>
# Universidad de Concepcion, Chile<br>
# cridonoso@inf.udec.cl<br>
#
#
# _Viernes 16 de Octubre del 2020_

# %% [markdown]
# **Web scrapping** es una tecnica informatica la cual nos permite extraer datos desde paginas web. Podemos separar las tecnicas dependiendo el contenido de la pagina:
# - contenido estatico: Paginas HTML fijas
# - contenido dinamico: Paginas interactivas HTML + javascript
#
# <br>
# Los sofware de scrapping simulan ser un ser humano extrayendo los datos que se encuentran de manera visible en la pagina. La automatizacion de este proceso nos permite extraer grandes volumenes de datos de manera rapida y precisa.

# %% [markdown]
# ### Librerias en Python
#
# Existen varias librerias en Python para realizar scrapping. A continuacion una tabla comparativa de los frameworks mas populares en python (*Fuente: [Python Web Scrapping - Kite, 2020](https://www.youtube.com/watch?v=zucvHSQsKHA)*)
#
#  <img src="./images/0.png" alt="Drawing" style="width: 600px;"/>
#
# En este tutorial utilizaremos **[BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/)**

# %%
# !pip install requests # para cargar URLs
# !pip install bs4
# Out:
# Requirement already satisfied: requests in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (from requests) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: bs4 in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/cridonoso/.conda/envs/tf2/lib/python3.8/site-packages (from beautifulsoup4->bs4) (2.0.1)

# %%
import requests 
from bs4 import BeautifulSoup

# %% [markdown]
# Lo primero que debemos hacer es **cargar el codigo html** desde la URL de la pagina de interes.
# <br><br>
# En este tutorial accederemos a las **ultimas publicaciones** del [arXiv](https://arxiv.org/)

# %% [markdown]
# Fijense que la consulta del buscador esta explicita en la URL por lo que podriamos modificar esta directamente
# <br><br>
# ```https://arxiv.org/search/?query=machine+learning&searchtype=all&abstracts=show&order=-announced_date_first&size=200```
# <br><br>
# en este caso, podemos crear una variable de tipo ```<list>``` para que reciba las palabras claves a buscar.

# %%
key_words = ['machine', 'learning']

str_keywords = '+'.join(key_words)

base = 'https://arxiv.org/search/?query={}&searchtype=all&abstracts=show&order=-announced_date_first&size=200'
url  = base.format(str_keywords)
print(url)
# Out:
# https://arxiv.org/search/?query=machine+learning&searchtype=all&abstracts=show&order=-announced_date_first&size=200

# %% [markdown]
# Una vez que tenemos nuestro link, podemos solicitar el codigo HTML de la pagina

# %%
# %%time
html_page = requests.get(url)
# Out:
# CPU times: user 26.4 ms, sys: 11.9 ms, total: 38.3 ms
# Wall time: 5.56 s

# %% [markdown]
# Una vez cargado el texto plano HTML debemos instanciar un Parser desde BeautifulSoup. Un parser es un **analizador sintactico**. En este caso BeautifulSoup nos permite trabajar con diferentes sintaxis, tales como HTML o XML

# %%
soup = BeautifulSoup(html_page.text, 'html.parser') # Instanciamos nuestro scrapper

# %% [markdown]
# Ahora debemos extraer la informacion que necesitamos. La forma mas directa de hacerlo es desde el navegador:
# 1. Abre la pagina web
# 2. Click derecho sobre el item de interes  <img src="./images/1.png" alt="Drawing" style="width: 600px;"/>
# 3. Click sobre inspeccionar <img src="./images/2.png" alt="Drawing" style="width: 200px;"/>
# 4. Revisa las etiquetas HTML para acceder al contenido en nuestro scrapper <img src="./images/3.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# En este ejemplo sacaremos los titulos de los papers, por lo tanto debemos extraer los parrafos ```<p>``` cuya clase tenga el nombre ```class="title is-5 mathjax">```

# %%
titulos = soup.find_all('p', attrs = {"class": 'title is-5 mathjax'})

# %% [markdown]
# La funcion ```find_all()``` retorna una lista de tipo ```bs4.element.Tag``` con las coincidencias de nuestra consulta.

# %%
for titulo in titulos:
    print(titulo.text.strip())
    break
# Out:
# Online and Distribution-Free Robustness: Regression and Contextual Bandits with Huber Contamination

# %% [markdown]
# Y ya esta!

# %% [markdown]
# ### Ejercicio: Obtieniendo los links de los papers

# %% [markdown]
# En este caso vamos a leer el contenedor HTML de manera un poco mas general. Segun nuestra consulta previa, todos los resultados vienen encapsulados en el tag ```<li>``` cuya clase es ```class="arxiv-result"```

# %%
resultados = soup.find_all('li', attrs = {"class": 'arxiv-result'})

# %%
titulos_list  = [] # Para guardar los titulos
pdf_link_list = [] # Para guardar los links

for res in resultados:
    titulo = res.find('p', attrs = {"class": "title is-5 mathjax"}) # Accedemos al tag del titulo
    link_content = res.find('p', attrs = {"class": "list-title is-inline-block"}) # accedemos al tag de los link
    link_content = link_content.find('span') # luego al tag de span dentro del tag anterior
    link_content = link_content.find_all('a') # finalmente extraemos todos los enlaces <a> dentro de ese tag
    links = [link.attrs.get('href') for link in link_content] # iteramos y extraemos el atributo href
    
    # Guardamos el titulo del paper 
    titulos_list.append(titulo.text.strip())
    
    # El primer link siempre sera pdf 
    pdf_link_list.append(links[0])

# %% [markdown]
# Ahora que tenemos todo guardado podemos crear un Frame de Pandas para ordenar los resultados

# %%
import pandas as pd

# %%
arxiv_hoy = pd.DataFrame() # Inicializamos un Frame vacio
arxiv_hoy['Titulo'] = titulos_list # Creamos columna con los titulos
arxiv_hoy['Link'] = pdf_link_list  # Creamos columna con los links al pdf

# %%
def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

arxiv_hoy.style.format({'Link': make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Titulo</th>        <th class="col_heading level0 col1" >Link</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row0_col0" class="data row0 col0" >Online and Distribution-Free Robustness: Regression and Contextual Bandits with Huber Contamination</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row0_col1" class="data row0 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04157">https://arxiv.org/pdf/2010.04157</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row1_col0" class="data row1 col0" >Automating Inference of Binary Microlensing Events with Neural Density Estimation</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row1_col1" class="data row1 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04156">https://arxiv.org/pdf/2010.04156</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row2_col0" class="data row2 col0" >Strongly lensed supernovae as a self-sufficient probe of the distance duality relation</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row2_col1" class="data row2 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04155">https://arxiv.org/pdf/2010.04155</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row3_col0" class="data row3 col0" >Olympus: a benchmarking framework for noisy optimization and experiment planning</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row3_col1" class="data row3 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04153">https://arxiv.org/pdf/2010.04153</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row4_col0" class="data row4 col0" >Automatic generation of reviews of scientific papers</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row4_col1" class="data row4 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04147">https://arxiv.org/pdf/2010.04147</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row5_col0" class="data row5 col0" >Leakage-Adjusted Simulatability: Can Models Generate Non-Trivial Explanations of Their Behavior in Natural Language?</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row5_col1" class="data row5 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04119">https://arxiv.org/pdf/2010.04119</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row6_col0" class="data row6 col0" >Interlocking Backpropagation: Improving depthwise model-parallelism</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row6_col1" class="data row6 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04116">https://arxiv.org/pdf/2010.04116</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row7_col0" class="data row7 col0" >A Machine Learning Framework for Computing the Most Probable Paths of Stochastic Dynamical Systems</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row7_col1" class="data row7 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04114">https://arxiv.org/pdf/2010.04114</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row8_col0" class="data row8 col0" >Information-Driven Adaptive Sensing Based on Deep Reinforcement Learning</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row8_col1" class="data row8 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04112">https://arxiv.org/pdf/2010.04112</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row9_col0" class="data row9 col0" >Set Prediction without Imposing Structure as Conditional Density Estimation</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row9_col1" class="data row9 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04109">https://arxiv.org/pdf/2010.04109</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row10_col0" class="data row10 col0" >Learning the Pareto Front with Hypernetworks</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row10_col1" class="data row10 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04104">https://arxiv.org/pdf/2010.04104</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row11_col0" class="data row11 col0" >Improved Techniques for Model Inversion Attack</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row11_col1" class="data row11 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04092">https://arxiv.org/pdf/2010.04092</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row12_col0" class="data row12 col0" >Reward-Biased Maximum Likelihood Estimation for Linear Stochastic Bandits</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row12_col1" class="data row12 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04091">https://arxiv.org/pdf/2010.04091</a></td>
#             </tr>
#             <tr>
#                         <th id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row13_col0" class="data row13 col0" >Classifying Songs with EEG</td>
#                         <td id="T_b8ca6a80_0c0c_11eb_9f80_a7132d732cc3row13_col1" class="data row13 col1" ><a target="_blank" href="https://arxiv.org/pdf/2010.04087">https://arxiv.org/pdf/2010.04087</a></td>
#             </tr>
#             <tr>
